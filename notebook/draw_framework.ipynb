# %%
import pandas as pd
import seaborn as sns

sns.set_style('whitegrid')

# %%
data = pd.read_csv('../data/processed/data.csv', index_col=0)
data
# Out:
#               9012    9384    9336    9173    9391    9392    9373    9374  \
# 2016-02-01     600  112800   52800  406400  764700  472200   72300   89900
# 2016-02-02  504000   84700   29800  172100  670600  518200   37200   88100
# 2016-02-03  467300   47500   10300  526800   60500   17200  269700  260700
# 2016-02-04  382200   11300   55400  532100   77900   61700  258300  227000
# 2016-02-05  298700  268600   99300  522600  282600  205800  284900  209400
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2018-01-27  215100   40200  301000   40600   13300   58500  319200  203700
# 2018-01-28  187800   10200  290200   34900   30800   44500  306200  216600
# 2018-01-29  163500   13000   62600   74700   19800   99000  297100  211600
# 2018-01-30  139000    8300   84000   77200   60400   57300   70000   83700
# 2018-01-31  138200  254800  102800  132800   96700   54100   69700   88100
#
# ...

# %%
data['9336'].iloc[220:320].plot(figsize=(8, 4))
# Out:
# <Axes: >

# %%
data['9336'].iloc[220:320].plot(figsize=(8, 4))
trend = data['9336'].rolling(10).mean()
season = data['9336'] - trend

trend.iloc[220:320].plot(alpha=0.8)
# Out:
# <Axes: >

# %%
trend.iloc[220:320].plot(figsize=(10, 6), color='darkorange')
# Out:
# <Axes: >

# %%
season.iloc[220:320].plot(figsize=(10, 6), color='green')
# Out:
# <Axes: >
